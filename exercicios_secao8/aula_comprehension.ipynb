# %% [markdown]
# ###List Comprehension
#
# - Utilizando list comprehension nõs podemos gerar novas listas com dados processados a partir de outro iterável
#
# Sintaxe da list comprehension
# - [dado for dado in iterável]

# %%
#Para entender melhor o acontecerá, devemos dividir a expressão em duas partes: a primeira parte: for numero in numeros/ a segunda parte: numero * 10 
numeros = [1,2,3,4,5]
res = [numero * 10 for numero in numeros]
print(res)
# Out:
# [10, 20, 30, 40, 50]

# %%
res = [numero / 2 for numero in numeros]
print(res)
# Out:
# [0.5, 1.0, 1.5, 2.0, 2.5]

# %%
def funcao(valor):
    return valor * valor

res = [funcao(numero) for numero in numeros]
print(res)
# Out:
# [1, 4, 9, 16, 25]

# %%
#List comprehension vs loop

#Loop
numeros = [1,2,3,4,5]
numeros_dobrados = []

for numero in numeros:
    numero_dobrados = numero * 2
    numeros_dobrados.append(numero_dobrados)
    
print(numeros_dobrados)
# Out:
# [2, 4, 6, 8, 10]

# %%
numeros_dobrados = [numero * 2 for numero in numeros]
print(numeros_dobrados)
# Out:
# [2, 4, 6, 8, 10]

# %%
nome = 'Geek University'
print([letra.upper() for letra in nome])
# Out:
# ['G', 'E', 'E', 'K', ' ', 'U', 'N', 'I', 'V', 'E', 'R', 'S', 'I', 'T', 'Y']

# %%
def caixa_alta(nome):
    nome = nome.replace(nome[0], nome[0].upper())
    return nome

amigos = ['maria', 'júlia', 'pedro', 'guilherme', 'vanessa']
print([caixa_alta(amigo) for amigo in amigos])
# Out:
# ['Maria', 'Júlia', 'Pedro', 'Guilherme', 'Vanessa']

# %%
print([numero * 3 for numero in range(1,10)])
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
print([bool(valor) for valor in [0,[], '', True,1, 3.14]])
# Out:
# [False, False, False, True, True, True]

# %%
print([str(numero) for numero in [1,2,3,4,5]])
# Out:
# ['1', '2', '3', '4', '5']

# %%
#Nós podemos adicionar estruturas condicionais lógicas as nossas List Comprehension

numeros = [1,2,3,4,5,6]

pares = [numero for numero in numeros if numero % 2 == 0]
pares
# Out:
# [2, 4, 6]

# %%
impares = [numero for numero in numeros if numero % 2 != 0]
impares
# Out:
# [1, 3, 5]

# %%
#Refatorar

#Qualquer número par por módulo de 2 é 0 e o é False em Python. not False = True
pares = [numero for numero in numeros if not numero % 2]
pares
# Out:
# [2, 4, 6]

# %%
#Qualquer número ímpar pormódulo de 2 é 1, e 1 é True em Python
impar = [numero for numero in numeros if numero % 2]
impar
# Out:
# [1, 3, 5]

# %%
res = [numero * 2 if numero % 2 == 0 else numero/2 for numero in numeros]
res
# Out:
# [0.5, 4, 1.5, 8, 2.5, 12]

# %%
#Listas aninhadas
listas = [[1,2,3], [4,5,6], [7,8,9]] #Matriz 3 X 3

print(listas[0][1])
print(listas[2][-2])
# Out:
# 2
# 8

# %%
#Iterando com loops em uma lista aninhadas
for lista in listas:
    for numero in lista:
        print(numero, end=' ')
# Out:
# 1 2 3 4 5 6 7 8 9

# %%
#Utilizando list comprehension

[[print(valor) for valor in lista] for lista in listas]
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# [[None, None, None], [None, None, None], [None, None, None]]

# %%
#Gerando uma matriz 3x3

tabuleiro = [[numero  for numero in range(1,4)] for valor in range(1,4)]
tabuleiro
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
#Gerando jogadas para o jogo da velha
velha = [['x' if numero % 2 == 0 else '0' for numero in range(1,4)] for valor in range(1,4)]
velha
# Out:
# [['0', 'x', '0'], ['0', 'x', '0'], ['0', 'x', '0']]

# %%
#Gerando valor inicial
print([['*' for i in range(1,4)] for j in range(1,4)])
# Out:
# [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']]

# %% [markdown]
# ###Dictionary Comprehension

# %% [raw]
# Pense no seguinte:
#
# Se quisermos criar uma lista fazemos:
# lista = [1,2,3,4]
#
# Se quisermos criar uma tupla:
# tupla: (1,2,3,4)
#
# Se quisermos criar um set (conjunto)
# conjunto = {1,2,3,4}
#
# Se quisermos criar um dicionário
# dicionario = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
#
# -> Sintaxy
# dic_comp = {chave:valor for valor in iterável}
# list_comp = [valor for valor in iterável]

# %%
numeros = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
quadrado = {chave:valor ** 2 for chave, valor in numeros.items()}
quadrado
# Out:
# {'a': 1, 'b': 4, 'c': 9, 'd': 16, 'e': 25}

# %%
numeros = [1,2,3,4,5]
quadrados = {valor: valor ** 2 for valor in numeros}
quadrados
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
numeros = [1,2,3,4,5,1,2]
quadrados = {valor: valor ** 2 for valor in numeros}
quadrados
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
chaves = 'abcde'
valores = [1,2,3,4,5]
mistura = {chaves[i]: valores[i] for i in range(0, len(chaves))}
mistura
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
#Exemplo com lógica condicional
numero = [1,2,3,4,5]
res = {num:('par' if num % 2 == 0 else 'impar') for num in numero}
res
# Out:
# {1: 'impar', 2: 'par', 3: 'impar', 4: 'par', 5: 'impar'}

# %% [markdown]
# ###Set Comprehension

# %% [raw]
# Set -> não aceita números repetidos e não possui ordenação

# %%
numeros = {num for num in range(1,7)}
numeros
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
numeros = {x ** 2 for x in range(10)}
numeros
# Out:
# {0, 1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
#Faça uma alteração para gerar um dicionário,ao invés de set
numeros = {x: x ** 2 for x in range(10)}
numeros
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
letras = {letra for letra in 'Geek University'}
letras
# Out:
# {' ', 'G', 'U', 'e', 'i', 'k', 'n', 'r', 's', 't', 'v', 'y'}

# %% [markdown]
# ###Recapitulando
